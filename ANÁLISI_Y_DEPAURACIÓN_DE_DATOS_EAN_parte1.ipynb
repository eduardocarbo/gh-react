# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardocarbo/gh-react/blob/main/AN%C3%81LISI_Y_DEPAURACI%C3%93N_DE_DATOS_EAN_parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ANALÍTICA Y DEPURACIÓN DE DATOS

# %% [markdown]
# #PANDAS
#
# **Pandas** es una librería que típicamente se utiliza para manipular datasets, generalmente vienen en formato csv (valores separados por comas). También se puede usar para vizualizar datos.
#
# Se basa en dos paquetes esenciales de Python, NumPy y Matplotlib.
#
#  **Numpy** proporciona objetos de matriz multidimensional para una fácil manipulación de datos **Matploylib** tiene poderosas capacidades de visualización de datos.
#
#  **Marco de datos en pandas** Se llaman DataFrames, los cuales son el núcleo de pandas.
#
#  A menudo trabajará con toneladas de datos. La forma de los datos puede variar, pero reducirlos a una estructura tabular , como en una hoja de cálculo.
#
#  **Explorando un dataframe**
#
#  **.head()**: Devuelve las primeras filas del dataframe. Con este método puede
#   ver explorar y ver rápidamente el contebido.
#
#  **.info()**: muestra información sobre cada una de las columnas, como el tipo de datos y la cantidad de valores faltantes.
#
# **.shape():** Es un atributo, no un método (se escribe sin paréntesis). Muestra el número de filas y el número de columnas del dataframe.
#
# **.describe():** Este método calcula algunas estadísticas de resumen para columnas numéricas como la media y la mediana. "count" es el número de valores que no faltan(non-missing values) en cada columna.

# %% [markdown]
# **Ejercicio 1:** Netflix es una de las paltaformas de transmisión de video y medios más populares. Tienen más de 8.000 películas o programas de televisión disponibles en su plataforma, a mediados de 20221, tiene más de 200 millones de suscriptores en tod el mundo. Este conjunto de datos tabulares consta de listados de todas las películas  y programas de televisión diponibles en Netflix, junto con detalles como: elenco, directores, año de estreno, duración, etc.
#
# vaya a la dirección : http://www.kaggles.com/datasetes/shivamb/netflix-shows
#
# y descargue el dataset.

# %% [markdown]
# **Ejercicio 2:** Abra o descomprima las carpeta archive.ziip, y copie el archivo  netflix_titles.csv en la carpeta de su preferencia

# %% [markdown]
# **Ejercicio 3:** Cargue la data en Colab , seleccionando el archivo netflix_titles.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8d43b2ba-a513-41fe-956b-6dea9c3bc15a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d43b2ba-a513-41fe-956b-6dea9c3bc15a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving netflix_titles.csv to netflix_titles.csv

# %% [markdown]
# **Ejercicio 4:** (i) importe la libreria pandas con el alias pd. Nombre com df al dataset, use la función read_csv del paquete pandas. (ii) Explore el dataframe usnado el método . head()

# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **Ejercicio 5:**Imprima información sobre los tipos de columnas y valores faltantes del df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# **Ejemplo 6:** Imprima el número de filas y columnas del df.¿Cuantas filas y cuántas columnas tiene el df?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# **Ejercicio 7:**Imprima algunas estadísticas de resumen que describe al df.¿Porqué en este caso las estadísticas no tienen mucho sentido?

# %%
df.describe()
#No tienen mucho sentido devido a que una media para un año de lanzamiento no tiene sentido. Es importante tenerr encuenta el tip ode data set se tiene.
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# **Ejercicio 8:** Imprime una array 2D Numpy de los valores de homelessness. Imprime los nombres de las columnas dle df imprime el indice dle df.

# %%
df.values
# Out:
# array([['s1', 'Movie', 'Dick Johnson Is Dead', ..., '90 min',
#         'Documentaries',
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'],
#        ['s2', 'TV Show', 'Blood & Water', ..., '2 Seasons',
#         'International TV Shows, TV Dramas, TV Mysteries',
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.'],
#        ['s3', 'TV Show', 'Ganglands', ..., '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure',
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.'],
#        ...,
#        ['s8805', 'Movie', 'Zombieland', ..., '88 min',
#         'Comedies, Horror Movies',
# ...

# %% [markdown]
# **Ordenar y dividir el dataframe:** Puede ordenar filas usando el método **sort_values**, pasando un onmbre de columna por el que desea ordenar. Establecer el argumento  ascendente en False ordenará los datos al revés.
#
# **Subconjuntos de columnas:** Puede seleccionar una columna del df, usando el nombre del Dataframe, seguido de corchetes([]) con un nombre de columna dentro. Para seleccionar varias columnas, necsita dos pares de corchetes (df[["col_a","col_b"]]). en este código, los corchetes internos y externos realizan diferentes tareas. Los corchetes exteriores son responsables de dividir el Dataframe en sibconjuntos, y lso corchetes internos crean una lista de nobmres de columnas apra dividir en subconjuntos.
#
#
# **Subconjunto de filas:** A veces se conoce como filtrado de filas o selección de filas. La formar más común de hacer esto es creando una condición lógica para filtrar. Se obtiene un valor Verdadero o Falso para cada fila. Podemos usar la condición lógica dentro de los corchetes para crear un subconjunto de las filas que nos interesan.
#
# **Subconjunto basados en texto:** podemos crear subconjuntos de fials en función de los datos de texto. Aquí, usamos el doble signo igual en la condición lógica para filtrar.
#
# **Subconjuntos basados en fechas:** podemos crear subconjuntos basados en fechas, usando el formato de fecha estándar internacional.
#
# **.isin()**: para fitrar varios valores de una variable categórica.

# %% [markdown]
# **Ejercicio 9:** Ordene el df por el año de lanzamiento del más antiguo al más reciente
#
# ¿Cuál es la serie más antigua, que figura en el dataset, disponible en Netflix?¿De qué año es?
#
# ¿Cuál es la película reciente, que figura en el dataset, disponible en Netflix?¿De que año es?

# %%
df.sort_values("release_year")
#La serie más antigua es del año 1925
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
df.sort_values("release_year",ascending = False)
#La palicula más reciente es la del 2021
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# **Ejercicio 10:** Ordene el DataFrame por Director (en forma ascendente) y luego por añ ode lanzamiento (en forma descendente). Guardo este subconjunto como df_director_year

# %%
df_director_year = df.sort_values(["director","release_year"],ascending=[True,False])
df_director_year.head(5)
# Out:
#      show_id   type       title         director  \
# 3537   s3538  Movie    Watchman      A. L. Vijay
# 6078   s6079  Movie   Abhinetri      A. L. Vijay
# 2389   s2390  Movie  Asura Guru     A. Raajdheep
# 5549   s5550  Movie   Salaakhen        A. Salaam
# 4049   s4050  Movie      Sarkar  A.R. Murugadoss
#
#                                                    cast country  \
# 3537  G.V. Prakash Kumar, Samyuktha Hegde, Suman, Ra...   India
# 6078  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...   India
# 2389  Vikram Prabhu, Subbaraju, Mahima Nambiar, Yogi...   India
# 5549  Shashi Kapoor, Sulakshana Pandit, Mehmood, Sud...   India
# 4049  Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...     NaN
#
#              date_added  release_year rating duration  \
# 3537  September 4, 2019          2019  TV-14   93 min
# 6078        May 1, 2018          2016  TV-14  131 min
# 2389      June 13, 2020          2020  TV-14  117 min
# 5549      April 1, 2017          1975  TV-14  134 min
# ...

# %% [markdown]
# **Ejercicio 11:** Cree un dataFrame llamado directors que tenga solo las columnas correspondientes a los directores del país, en ese orden, imprime el encabezado de ditectcountries

# %%
directors = df["director"]
directors.head(10)
# Out:
# 0                  Kirsten Johnson
# 1                              NaN
# 2                  Julien Leclercq
# 3                              NaN
# 4                              NaN
# 5                    Mike Flanagan
# 6    Robert Cullen, José Luis Ucha
# 7                     Haile Gerima
# 8                  Andy Devonshire
# 9                   Theodore Melfi
# Name: director, dtype: object

# %% [markdown]
# **Ejercicio 12:** Crre un DataFrame llamado **directcountries** que contenga solo las colmnas correspondientes a los directores y el país, en ese orden. Imprima el encabezado de **ditectcountries**

# %%
directcountries = df[["director","country"]]
directcountries.head()
# Out:
#           director        country
# 0  Kirsten Johnson  United States
# 1              NaN   South Africa
# 2  Julien Leclercq            NaN
# 3              NaN            NaN
# 4              NaN          India

# %% [markdown]
# **Ejercicio 13:** Cree un DataFrame llamado criolllas que sea el resultado de filtrar df por casos dende la película o la serie haya sido de Colombia.

# %%
criollas = df[df["country"]=="Colombia"]
criollas.head(5)
# Out:
#      show_id     type                        title        director  \
# 278     s279    Movie  Lokillo: Nothing's the Same  Julián Gaviria
# 288     s289  TV Show      Las muñecas de la mafia             NaN
# 744     s745  TV Show                  Locombianos             NaN
# 753     s754  TV Show       Newly Rich, Newly Poor             NaN
# 1232   s1233    Movie                   Dogwashers   Carlos Moreno
#
#                                                    cast   country  \
# 278                                      Lokillo Florez  Colombia
# 288   Amparo Grisales, Fernando Solórzano, Angelica ...  Colombia
# 744   Freddy Beltrán, Pamela Ospina, Diego Camargo, ...  Colombia
# 753   Martín Karpan, Carolina Acevedo, Jhon Álex Tor...  Colombia
# 1232  Christian Tappan, Anderson Ballesteros, John Á...  Colombia
#
#            date_added  release_year rating  duration  \
# 278   August 12, 2021          2021  TV-MA    64 min
# 288   August 10, 2021          2018  TV-MA  1 Season
# ...

# %% [markdown]
# **Ejercicio 14:** Cree un DataFrame llamado criollas_recientes, que sea el resutlado de filtrar criollas, donde el año de lanzamiento de las películas, series o novelas sea mayor o igual a 2018

# %%
criollas_recientes = criollas[criollas["release_year"]>=2018]
criollas_recientes
# Out:
#      show_id     type                                       title  \
# 278     s279    Movie                 Lokillo: Nothing's the Same
# 288     s289  TV Show                     Las muñecas de la mafia
# 744     s745  TV Show                                 Locombianos
# 1232   s1233    Movie                                  Dogwashers
# 1523   s1524    Movie                   An Unremarkable Christmas
# 2093   s2094  TV Show                         Her Mother's Killer
# 2134   s2135  TV Show                             The Great Heist
# 2329   s2330  TV Show                                All For Love
# 2499   s2500  TV Show                 The Queen and the Conqueror
# 2567   s2568    Movie                              Death Can Wait
# 2868   s2869  TV Show                              Always a Witch
# 3185   s3186  TV Show                            The Road to Love
# 3265   s3266    Movie                   El sendero de la anaconda
# ...
